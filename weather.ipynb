# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\basic\weather.csv")

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
data[data.isnull().any(axis=1)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Sunshine WindGustDir  WindGustSpeed  \
# 113     12.7     28.6       6.6       8.6           W           50.0
# 118     11.7     27.6       0.0       8.1           W           48.0
# 127     10.8     29.2       0.0       7.5           E           50.0
# 138     12.5     29.9       0.0      10.7          NW           43.0
# 140     11.5     29.3       0.0       8.0          NW           46.0
# 174      7.5     19.0       0.0       6.8         ENE           26.0
# 176      5.0     20.9       0.0       8.9         WNW           22.0
# 180     -2.1     13.8       0.2       9.5         NNW           22.0
# 189     -0.2     18.1       0.0       9.4          NW           24.0
# 193      9.4     19.2       0.0       7.7         NaN           24.0
# 195      2.2     18.6       0.0       9.2         NNW           31.0
# 200     -2.7     18.1       0.0       9.3           W           52.0
# 208      4.9     18.1       5.2       8.5         NNW           22.0
# ...

# %%
del data['Evaporation']

# %%
clean_data = data.copy()
humidity_level=24.99
clean_data['high_humidity_label'] = (clean_data['Humidity3pm'] > humidity_level)*1
print(clean_data['high_humidity_label'])
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 361    0
# 362    0
# 363    1
# 364    1
# 365    0
# Name: high_humidity_label, Length: 366, dtype: int32

# %%
y=clean_data[['high_humidity_label']].copy()
y
# Out:
#      high_humidity_label
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 361                    0
# 362                    0
# 363                    1
# 364                    1
# 365                    0
#
# [366 rows x 1 columns]

# %%
clean_data['Humidity3pm'].head()
# Out:
# 0    29
# 1    36
# 2    69
# 3    56
# 4    49
# Name: Humidity3pm, dtype: int64

# %%
y.head()
# Out:
#    high_humidity_label
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
plt.plot(data["MinTemp"])
plt.ylabel("Mean daily temperature (°C)");

# %%
data.plot(x="MaxTemp", y="Humidity3pm", kind="scatter")
scipy.stats.pearsonr(data["MaxTemp"], data["Humidity3pm"])
# Out:
# PearsonRResult(statistic=-0.5333268827863179, pvalue=2.7353505337650322e-28)

# %%
plt.scatter(data["MinTemp"], data["Pressure3pm"]);
scipy.stats.pearsonr(data["MinTemp"], data["Pressure3pm"])
# Out:
# PearsonRResult(statistic=-0.4980069218031209, pvalue=2.4594101764613544e-24)

# %%
plt.scatter(data["MaxTemp"], data["Temp9am"])
scipy.stats.pearsonr(data["MaxTemp"], data["Temp9am"])
# Out:
# PearsonRResult(statistic=0.8706035194583102, pvalue=3.560073758809976e-114)

# %%
data.plot(x="Pressure3pm", y="Cloud9am", kind="scatter");

# %%
obs = scipy.stats.norm(loc=10, scale=2).rvs(1000)
scipy.stats.norm.fit(obs)
# Out:
# (10.010257664697768, 1.9792626360087051)

# %%
mu, sigma = scipy.stats.norm.fit(obs)
fitted = scipy.stats.norm(mu, sigma)
plt.hist(obs, bins=30, density=True, alpha=0.5);
x = np.linspace(obs.min(), obs.max(), 100)
plt.plot(x, fitted.pdf(x), lw=3);
